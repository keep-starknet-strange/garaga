# %%
x = -15132376222941642752 
k = 12
r = (x**4-x**2+1)
q = ((x-1)**2)//3 * r + x
h = (q**k - 1) // r

lam = -x +q
m = lam // r

p = 5044125407647214251
h3 = ...

assert(h == 27 * p * h3)
assert(m == 3 * p^2)

assert(gcd(3, h3) == 1)
assert(gcd(p^2, h3) == 1)
assert(gcd(3, h3) == 1)
assert(gcd(p, h3) == 1)
assert(gcd(p, 27 * h3) == 1)
assert(gcd(27, p * h3) == 1)

Fq = GF(q, proof=False)
# Define the polynomial ring over Fq
R.<w> = PolynomialRing(Fq)
# Irreducible polynomial
p_irr = w^12 - 2*w^6 + 2
# Define the extension field Fq12
Fq12 = Fq.extension(p_irr, 'z')
z = Fq12.gen()

ONE = Fq12(1)

w27 = ONE.nth_root(27); 
wp = ONE.nth_root(p);

assert(w27^9 != ONE)

# %%
from random import randrange
def sample_27th_root(): 
    i = randrange(27)
    return [w27^i, i]

def sample_pth_root(): 
    i = randrange(p)
    return [wp^i, i]

def sample_h3_root():
    x = Fq12.random_element(); 
    x = x^r 
    x = x^27 
    x = x^p 
    
    assert(x^h3 == ONE)
    
    return x

# %%
def has_27th_root_contribution(x): 
    # checks if x has a 27th root of unity contribution 
    try: 
        c=x.nth_root(3)
        print(f"27th root contribution: {c}")
        return False
    except: 
        return True
  


def has_pth_root_contribution(x): 
    # checks if x has a pth root of unity contribution 
    try: 
        c=x.nth_root(p)
        print(f"pth root contribution: {c}")
        return False
    except Exception as e:
        print(f"Exception : {e}")
        return True
    
def clear_pth_root2_factor(x): 
    check = has_pth_root_contribution(x)
    print(f"check : {check}")
    if not check: 
        print(f"No pth root contribution")
        return ONE 
    
    v = 27 * h3 
    wj = x^v 
    
    v_inv = inverse_mod(v, p)
    s = (-1 * v_inv) % p
    
    return wj^s

def clear_27th_root2_factor(x): 
    if not has_27th_root_contribution(x): 
        print(f"No 27th root contribution")
        return ONE 
    
    v = p * h3 
    wj = x^v 
    
    v_inv = inverse_mod(v, 27)
    s = (-1 * v_inv) % 27
    
    return wj^s

# %%
for i in range(1): 
    f = Fq12.random_element()
    f = 2098802705043851873713543722281531632063480477899226643409611072851184785916596261525222650132053148512283553928493*z^11 + 1091947292173612475687433132112898886918806692432160998893221576529845880336410428477144634157960170947124999698218*z^10 + 736572895361159411171229673578832162203106508956380780304214064631415333320493547458925147941678699531071949550566*z^9 + 2721317655202656959113201375593409989967219906235336555426408631433349511576655778685314127793282994544073527679063*z^8 + 451311038009039876347621886227982967215156404158120765526475064409228327034646246274182431549200334179203807241838*z^7 + 3473150170578346500816286845588001643575996472187198401458492537347524698625205088124185405269064795725567877351027*z^6 + 2841270419608216754389423227536865909060468240291342841351728506675218699271683329235707543767811395969266952925144*z^5 + 3369849586433955999690457704772672312904928107641169596672035513827850141757769757502340074571474213192989436658567*z^4 + 3428234078568970655411994910327409952546504435773550970588628794170660376604667814028107473031134361894128894556210*z^3 + 2907396023143940328813695567924736077595710168127480034021797579258787971389145981206805880123370385211072587741170*z^2 + 1187568685386508294068275145898969985498011946828125304755176825279797228901585707382970265738187608693963934367592*z + 1215217330854537251988006867345303231443282415618969103963304857660409025284221754770333416962910288984426342787697
    print(f"f : {f}")
    f = f**r # it will always come as r-th residue in the honest execution
    print(f"f^r : {f}")
    wp_shift = clear_pth_root2_factor(f)
    print(f"wp_shift : {wp_shift}")
    w27_shift = clear_27th_root2_factor(f)
    
    f_shifted = f * wp_shift * w27_shift

    root = f_shifted.nth_root(lam)
    assert f_shifted == root^lam
    print('step: ', i, "ok, root: ", root)
# Out:
# f : 2098802705043851873713543722281531632063480477899226643409611072851184785916596261525222650132053148512283553928493*z^11 + 1091947292173612475687433132112898886918806692432160998893221576529845880336410428477144634157960170947124999698218*z^10 + 736572895361159411171229673578832162203106508956380780304214064631415333320493547458925147941678699531071949550566*z^9 + 2721317655202656959113201375593409989967219906235336555426408631433349511576655778685314127793282994544073527679063*z^8 + 451311038009039876347621886227982967215156404158120765526475064409228327034646246274182431549200334179203807241838*z^7 + 3473150170578346500816286845588001643575996472187198401458492537347524698625205088124185405269064795725567877351027*z^6 + 2841270419608216754389423227536865909060468240291342841351728506675218699271683329235707543767811395969266952925144*z^5 + 3369849586433955999690457704772672312904928107641169596672035513827850141757769757502340074571474213192989436658567*z^4 + 342823407856897065
# ...
